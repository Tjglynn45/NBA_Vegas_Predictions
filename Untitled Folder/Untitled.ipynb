# %%
import nba_api.stats.endpoints
from nba_api.stats.static import players
from nba_api.stats.static import teams
from nba_api.stats.endpoints import TeamYearByYearStats
import pandas as pd
import itertools

# %%
team_dict = teams.get_teams()

# %%
team_dict
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Atlanta',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966},
#  {'id': 1610612742,
# ...

# %%
team_id = [tid['id'] for tid in team_dict]
team_id
# Out:
# [1610612737,
#  1610612738,
#  1610612739,
#  1610612740,
#  1610612741,
#  1610612742,
#  1610612743,
#  1610612744,
#  1610612745,
#  1610612746,
#  1610612747,
#  1610612748,
#  1610612749,
#  1610612750,
#  1610612751,
#  1610612752,
#  1610612753,
#  1610612754,
#  1610612755,
#  1610612756,
#  1610612757,
#  1610612758,
#  1610612759,
#  1610612760,
#  1610612761,
#  1610612762,
#  1610612763,
#  1610612764,
#  1610612765,
#  1610612766]

# %%
Team_YearStats = []

for i in team_id:
    temp = TeamYearByYearStats(i).get_data_frames()[0]
    Team_YearStats.append(temp)
pd.concat(Team_YearStats)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
# ...

# %%
Team_YearStats

# %%
df = pd.DataFrame(Team_YearStats)

# %%
df
# Out:
#                                                     0
# 0   <nba_api.stats.endpoints.teamyearbyyearstats.T...
# 1   <nba_api.stats.endpoints.teamyearbyyearstats.T...
# 2   <nba_api.stats.endpoints.teamyearbyyearstats.T...
# 3   <nba_api.stats.endpoints.teamyearbyyearstats.T...
# 4   <nba_api.stats.endpoints.teamyearbyyearstats.T...
# 5   <nba_api.stats.endpoints.teamyearbyyearstats.T...
# 6   <nba_api.stats.endpoints.teamyearbyyearstats.T...
# 7   <nba_api.stats.endpoints.teamyearbyyearstats.T...
# 8   <nba_api.stats.endpoints.teamyearbyyearstats.T...
# 9   <nba_api.stats.endpoints.teamyearbyyearstats.T...
# 10  <nba_api.stats.endpoints.teamyearbyyearstats.T...
# 11  <nba_api.stats.endpoints.teamyearbyyearstats.T...
# 12  <nba_api.stats.endpoints.teamyearbyyearstats.T...
# 13  <nba_api.stats.endpoints.teamyearbyyearstats.T...
# 14  <nba_api.stats.endpoints.teamyearbyyearstats.T...
# 15  <nba_api.stats.endpoints.teamyearbyyearstats.T...
# ...

# %%
temp = TeamYearByYearStats(1610612747).get_data_frames()[0]

# %%
temp
# Out:
#        TEAM_ID    TEAM_CITY TEAM_NAME     YEAR  GP  WINS  LOSSES  WIN_PCT  \
# 0   1610612747  Minneapolis    Lakers  1948-49  60    44      16    0.733
# 1   1610612747  Minneapolis    Lakers  1949-50  68    51      17    0.750
# 2   1610612747  Minneapolis    Lakers  1950-51  68    44      24    0.647
# 3   1610612747  Minneapolis    Lakers  1951-52  66    40      26    0.606
# 4   1610612747  Minneapolis    Lakers  1952-53  70    48      22    0.686
# ..         ...          ...       ...      ...  ..   ...     ...      ...
# 68  1610612747  Los Angeles    Lakers  2016-17  82    26      56    0.317
# 69  1610612747  Los Angeles    Lakers  2017-18  82    35      47    0.427
# 70  1610612747  Los Angeles    Lakers  2018-19  82    37      45    0.451
# 71  1610612747  Los Angeles    Lakers  2019-20  71    52      19    0.732
# 72  1610612747  Los Angeles    Lakers  2020-21  72    42      30    0.583
#
#     CONF_RANK  DIV_RANK  ...  OREB  DREB   REB   AST    PF  STL   TOV  BLK  \
# ...

# %%
T_G=leaguegamefinder.LeagueGameFinder(season_nullable='2020-21').get_data_frames()[0]
pd.to_datetime(T_G['GAME_DATE'])
T_G.set_index('GAME_DATE')
# Out:
#            SEASON_ID     TEAM_ID TEAM_ABBREVIATION  \
# GAME_DATE
# 2021-07-17     42020  1610612749               MIL
# 2021-07-17     42020  1610612756               PHX
# 2021-07-14     42020  1610612756               PHX
# 2021-07-14     42020  1610612749               MIL
# 2021-07-11     42020  1610612749               MIL
# ...              ...         ...               ...
# 2020-07-25     22020  1611661328               SEA
# 2020-02-15     32020  1621980049               ARI
# 2020-02-15     32020  1621980046               LEG
# 2020-02-15     32020  1621980053               KIP
# 2020-02-15     32020  1621980041               BEL
#
#                                      TEAM_NAME     GAME_ID      MATCHUP WL  \
# GAME_DATE
# 2021-07-17                     Milwaukee Bucks  0042000405    MIL @ PHX  W
# 2021-07-17                        Phoenix Suns  0042000405  PHX vs. MIL  L
# 2021-07-14                        Phoenix Suns  0042000404    PHX @ MIL  L
# ...

# %%
Team_GameStats = T_G[T_G['TEAM_ID'] == 1610612749]

# %%
Team_GameStats
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION        TEAM_NAME     GAME_ID  \
# 0        42020  1610612749               MIL  Milwaukee Bucks  0042000405
# 3        42020  1610612749               MIL  Milwaukee Bucks  0042000404
# 4        42020  1610612749               MIL  Milwaukee Bucks  0042000403
# 7        42020  1610612749               MIL  Milwaukee Bucks  0042000402
# 9        42020  1610612749               MIL  Milwaukee Bucks  0042000401
# ...        ...         ...               ...              ...         ...
# 2596     22020  1610612749               MIL  Milwaukee Bucks  0022000006
# 2610     22020  1610612749               MIL  Milwaukee Bucks  0022000003
# 2642     12020  1610612749               MIL  Milwaukee Bucks  0012000043
# 2686     12020  1610612749               MIL  Milwaukee Bucks  0012000022
# 2706     12020  1610612749               MIL  Milwaukee Bucks  0012000009
#
#        GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# ...

# %%
from nba_api.stats.endpoints import leaguegamefinder

# %%
for x in team_id:
    
    Team_games = []
    temp = leaguegamefinder.LeagueGameFinder(season_nullable='2020-21').get_data_frames()[0]
    Team_games.append(temp)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
# ...

# %%
Team_games
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION        TEAM_NAME     GAME_ID  \
# 0        42020  1610612751               BKN    Brooklyn Nets  0042000217
# 1        42020  1610612751               BKN    Brooklyn Nets  0042000216
# 2        42020  1610612751               BKN    Brooklyn Nets  0042000215
# 3        42020  1610612751               BKN    Brooklyn Nets  0042000214
# 4        42020  1610612751               BKN    Brooklyn Nets  0042000213
# ...        ...         ...               ...              ...         ...
# 3351     21983  1610612751               NJN  New Jersey Nets  0028300050
# 3352     21983  1610612751               NJN  New Jersey Nets  0028300039
# 3353     21983  1610612751               NJN  New Jersey Nets  0028300030
# 3354     21983  1610612751               NJN  New Jersey Nets  0028300012
# 3355     21983  1610612751               NJN  New Jersey Nets  0028300005
#
#        GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# ...
